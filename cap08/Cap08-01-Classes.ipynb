# %%
# Criando uma classe chamada Livro
class Livro():
    # O método __init__  vai inicializar cada objeto criado a partir desta classe
    # (self) é uma referência a cada atributo da própria classe (e não de uma classe mãe, por exemplo)
    def __init__(self):
        # Atributos são propriedades
        self.titulo = 'Vasco - O maior time do Brasil'
        self.isbn = 9988888
        print("Construtor chamado para criar um objeto desta classe.")
    # Métodos são funções que executam ações nos objetos da classe
    def imprime(self):
        print("Foi criado o livro %s com ISBN %d" %(self.titulo, self.isbn))

# %% [markdown]
# Em Python, a palavra reservada self é uma referência ao objeto atual da classe. Quando um objeto é criado a partir de uma classe, self é utilizado para se referir a esse objeto específico.

# %%
# Criando uma instância da classe Livro

Livro1 = Livro()
# Out:
# Construtor chamado para criar um objeto desta classe.

# %%
# O objeto Livro1 é do tipo Livro

type(Livro1)
# Out:
# __main__.Livro

# %%
# Atributo do objeto Livro1

Livro1.titulo
# Out:
# 'Vasco - O maior time do Brasil'

# %%
# Método do objeto Livro1

Livro1.imprime()
# Out:
# Foi criado o livro Vasco - O maior time do Brasil com ISBN 9988888

# %%
# Criando a classe Livro com parâmetros no método construtor

class Livro():

    def __init__(self, titulo, isbn):
        self.titulo = titulo
        self.isbn = isbn
        print("Construtor chamado para criar um objeto desta classe.")
    
    def imprime(self, titulo, isbn):
        print("Foi criado o livro %s com ISBN %d" %(self.titulo, self.isbn))

# %%
Livro2 = Livro("Vasco da Gama", 21081898)
# Out:
# Construtor chamado para criar um objeto desta classe.

# %%
Livro2.titulo
# Out:
# 'Vasco da Gama'

# %%
Livro2.imprime("titulo", 0000)
# Out:
# Foi criado o livro Vasco da Gama com ISBN 21081898

# %%
# Criando a classe 

class Algoritmo():
    
    def __init__(self, tipo_algo):
        self.tipo = tipo_algo
        print("Construtor chamado para criar um objeto desta classe.")

# %%
# Criando um objeto a partir da classe 

algo1 = Algoritmo(tipo_algo = 'Random Forest')
# Out:
# Construtor chamado para criar um objeto desta classe.

# %%
# Criando um objeto a partir da classe 
algo2 = Algoritmo(tipo_algo = 'Deep Learning')
# Out:
# Construtor chamado para criar um objeto desta classe.

# %%
algo1.tipo
# Out:
# 'Random Forest'

# %%
algo2.tipo
# Out:
# 'Deep Learning'
